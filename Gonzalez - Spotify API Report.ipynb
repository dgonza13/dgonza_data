# %% [markdown]
# # Dominic's Spotify API Report (15 October 2023)
#
# I plan to take one of the playlists from my Spotify library and analyze the danceability, energy, and liveliness of the playlist and understand the differences in the type of music I listen to. I think it would be intriguing to compare this data across the music and songs contained in this playlist.
#
# Theoretical Hypothesis - I have a playlist (The Ultimate Mixtape) on Spotify that contains 478 songs (28 hrs and 12 mins). I hypothesize that the danceability, energy, and liveliness will be on the higher end as many of the songs on the playlist include more types of genres like pop, country, and rock.
#
# Statistical Hypothesis - I hypothesize that the danceability, energy, and liveliness will contain higher numbers as compared to that of acoustics and instrumentals.
#
# The source and structure of the data used in this report originated from Spotify for Developers. This is a useful tool presented directly from Spotify that allows the user to utilize Web API to retrieve information from the Spotify catalog about artists, tracks, and playlists. It contains large amounts of data that are useful for working with.

# %%
import requests
import pandas as pd
import base64
import json
import urllib

# %%
Client_ID = pd.read_csv('Spotify_IDs')['Client_ID'].iloc[0]

# %%
Client_Secret = pd.read_csv('Spotify_IDs')['Client_Secret'].iloc[0]

# %%
# Client_ID

# %%
# Client_Secret

# %%
client_cred = base64.b64encode(str(Client_ID + ":" + Client_Secret).encode("ascii"))

# %%
# client_cred

# %%
headers = {"Authorization": "Basic {}".format(client_cred.decode("ascii"))}

# %%
# headers

# %%
payload = {'grant_type' : 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'

# %%
session_key_response = requests.post(url = url, data = payload, headers = headers)

# %%
session_key_response.status_code
# Out:
# 200

# %%
# session_key_response.json()['access_token']

# %%
session_header_key = session_key_response.json()

# %%
key = session_header_key['access_token']

# %%
session_headers = {"Authorization": "Bearer {}".format(key)}

# %%
# session_headers

# %%
search_url = 'https://api.spotify.com/v1/playlists/54iGOfVAwrFokblOdcUAjB'

# %%
search_url
# Out:
# 'https://api.spotify.com/v1/playlists/54iGOfVAwrFokblOdcUAjB'

# %%
search_response = requests.get(url = search_url, headers = session_headers)
search_response.status_code
# Out:
# 200

# %%
search_data = search_response.json()

# %%
search_data.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
search_data['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
search_data['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
search_df = pd.DataFrame(search_data['tracks']['items'])

# %%
search_df.head()
# Out:
#                added_at                                           added_by  \
# 0  2023-08-20T20:16:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 1  2023-08-20T20:16:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 2  2023-08-20T20:16:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 3  2023-08-20T20:16:26Z  {'external_urls': {'spotify': 'https://open.sp...
# 4  2023-08-20T20:16:26Z  {'external_urls': {'spotify': 'https://open.sp...
#
#    is_local primary_color                                              track  \
# 0     False          None  {'album': {'album_type': 'album', 'artists': [...
# 1     False          None  {'album': {'album_type': 'album', 'artists': [...
# 2     False          None  {'album': {'album_type': 'album', 'artists': [...
# %%
features_response = requests.get(url = audio_features_url, headers = session_headers)
features_response.status_code
# Out:
# 200

# %%
features = features_response.json()

# %%
features_df = pd.DataFrame(features['audio_features'])

# %%
features_df.head(50)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.532   0.767    7    -5.509     1       0.0574      0.002870
# 1          0.502   0.890    4    -5.175     1       0.0364      0.000147
# 2          0.541   0.960    0    -2.947     0       0.0505      0.066300
# 3          0.574   0.913    6    -4.793     0       0.1330      0.061000
# 4          0.454   0.913    9    -4.008     1       0.1070      0.408000
# 5          0.453   0.987    8    -4.485     1       0.0889      0.019500
# 6          0.502   0.924    4    -6.299     1       0.0503      0.012700
# 7          0.653   0.730    5   -10.613     1       0.0429      0.011500
# 8          0.482   0.617    4   -12.931     0       0.0458      0.005430
# 9          0.572   0.835    0    -6.219     1       0.0317      0.171000
# 10         0.465   0.907   11    -6.404     0       0.1130      0.024100
# 11         0.540   0.982    4    -2.962     0       0.0458      0.435000
# 12         0.448   0.908   11    -3.818     0       0.1470      0.032100
# 13         0.407   0.955    2    -4.164     1       0.1640      0.025100
# 14         0.761   0.711    9    -7.989     1       0.0604      0.017400
# 15         0.262   0.777   11    -8.671     1       0.0632      0.010900
# 16         0.649   0.903    7    -3.677     1       0.0318      0.000841
# 17         0.599   0.931    7    -4.653     1       0.0735      0.030200
# 18         0.673   0.814    9    -5.411     1       0.0367      0.013300
# 19         0.548   0.691    4   -13.553     0       0.0369      0.015000
# 20         0.357   0.653    9    -5.554     1       0.0654      0.082800
# 21         0.379   0.760    9   -10.961     1       0.0378      0.002980
# 22         0.611   0.882    9   -11.225     1       0.0538      0.084700
# 23         0.515   0.766    7   -12.768     1       0.0343      0.024900
# 24         0.741   0.580    4    -9.050     1       0.0304      0.117000
# 25         0.705   0.806    0    -4.830     1       0.0814      0.229000
# 26         0.628   0.934   11    -6.026     1       0.0527      0.006820
# 27         0.381   0.894    7    -8.638     1       0.0370      0.025800
# 28         0.524   0.955    0    -7.081     1       0.0411      0.007170
# 29         0.653   0.677    0   -12.244     1       0.0396      0.249000
# 30         0.562   0.609    3    -7.063     0       0.0271      0.026400
# 31         0.644   0.799    4   -10.856     0       0.0598      0.082100
# 32         0.351   0.889    8    -3.513     1       0.1150      0.001620
# 33         0.616   0.910    8    -3.316     0       0.1240      0.010900
# 34         0.593   0.814    9    -4.802     1       0.1660      0.019700
# 35         0.664   0.785    8    -4.985     1       0.0688      0.016600
# 36         0.588   0.860    8    -4.461     1       0.0767      0.028000
# 37         0.614   0.840    9    -4.624     1       0.0410      0.006890
# 38         0.614   0.792    0    -4.476     0       0.0636      0.040700
# 39         0.791   0.796   10    -6.630     1       0.0901      0.021000
# 40         0.557   0.796    3    -4.147     1       0.0482      0.004110
# 41         0.531   0.881    9    -3.909     1       0.0402      0.003180
# 42         0.586   0.896    3    -4.572     1       0.1100      0.114000
# 43         0.613   0.917    8    -4.754     1       0.0637      0.000398
# 44         0.623   0.869    5    -3.376     1       0.0481      0.008410
# 45         0.591   0.866    2    -2.877     1       0.0536      0.057600
# 46         0.541   0.910    8    -4.725     1       0.0520      0.000927
# 47         0.568   0.865    5    -3.653     1       0.0486      0.006320
# 48         0.664   0.739    5    -5.342     0       0.0713      0.006840
# 49         0.581   0.860   10    -3.459     1       0.0360      0.000501
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000513    0.3900    0.755  127.361  audio_features
# 1           0.011700    0.2170    0.259  133.520  audio_features
# 2           0.000002    0.3440    0.812  122.803  audio_features
# 3           0.001580    0.1560    0.423  115.728  audio_features
# 4           0.000271    0.2480    0.521  137.688  audio_features
# 5           0.283000    0.2680    0.316  123.544  audio_features
# 6           0.000000    0.1620    0.922  149.186  audio_features
# 7           0.000010    0.0776    0.894  108.709  audio_features
# 8           0.000146    0.2840    0.718  125.697  audio_features
# 9           0.000377    0.0702    0.795  129.981  audio_features
# 10          0.001180    0.1300    0.681  117.293  audio_features
# 11          0.000034    0.0457    0.910  126.294  audio_features
# 12          0.000017    0.0703    0.383  145.267  audio_features
# 13          0.000000    0.3470    0.508  177.480  audio_features
# 14          0.000101    0.0652    0.947  105.448  audio_features
# 15          0.113000    0.1200    0.264  152.500  audio_features
# 16          0.000351    0.1220    0.412  121.841  audio_features
# 17          0.000067    0.3920    0.536  140.123  audio_features
# 18          0.002930    0.3430    0.728  147.193  audio_features
# 19          0.106000    0.1440    0.667  137.145  audio_features
# 20          0.000000    0.0844    0.522  176.647  audio_features
# 21          0.029600    0.1040    0.491   99.436  audio_features
# 22          0.000001    0.1920    0.605  117.932  audio_features
# 23          0.001030    0.4550    0.774  146.911  audio_features
# 24          0.000033    0.2120    0.944  127.402  audio_features
# 25          0.000000    0.0676    0.763  117.945  audio_features
# 26          0.000011    0.0852    0.491  126.538  audio_features
# 27          0.000000    0.0251    0.797  205.528  audio_features
# 28          0.000009    0.6590    0.869  133.849  audio_features
# 29          0.000000    0.4030    0.888  114.370  audio_features
# 30          0.000000    0.1700    0.512  130.753  audio_features
# 31          0.001540    0.0550    0.889  108.381  audio_features
# 32          0.000000    0.0707    0.645  136.971  audio_features
# 33          0.000000    0.0806    0.714  150.038  audio_features
# 34          0.000000    0.1800    0.480  146.919  audio_features
# 35          0.000000    0.0496    0.688  103.910  audio_features
# 36          0.000000    0.5640    0.622  129.945  audio_features
# 37          0.000000    0.1190    0.791  119.014  audio_features
# 38          0.000000    0.3770    0.809  160.011  audio_features
# 39          0.000000    0.0930    0.653  127.997  audio_features
# 40          0.000000    0.0951    0.457  127.999  audio_features
# 41          0.000000    0.1290    0.268  130.104  audio_features
# 42          0.000000    0.1750    0.381   94.954  audio_features

#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2SiX...       210173
# 1   https://api.spotify.com/v1/audio-analysis/57bg...       292880
# 2   https://api.spotify.com/v1/audio-analysis/0rmG...       222707
# 3   https://api.spotify.com/v1/audio-analysis/2zYz...       208400
# 4   https://api.spotify.com/v1/audio-analysis/7ACx...       293183
# 5   https://api.spotify.com/v1/audio-analysis/0G21...       273480
# 6   https://api.spotify.com/v1/audio-analysis/1hlv...       219667
# 7   https://api.spotify.com/v1/audio-analysis/4Jfu...       220311
# 8   https://api.spotify.com/v1/audio-analysis/58XW...       252493
# 9   https://api.spotify.com/v1/audio-analysis/7N3P...       241600
# 10  https://api.spotify.com/v1/audio-analysis/6koo...       238973
# 11  https://api.spotify.com/v1/audio-analysis/6gQU...       265773
# 12  https://api.spotify.com/v1/audio-analysis/5KaR...       285696
# 13  https://api.spotify.com/v1/audio-analysis/18ES...       201107
# 14  https://api.spotify.com/v1/audio-analysis/6qUE...       310387
# 15  https://api.spotify.com/v1/audio-analysis/0rFW...       182733
# 16  https://api.spotify.com/v1/audio-analysis/5u5F...       225947
# 17  https://api.spotify.com/v1/audio-analysis/549G...       270427
# 18  https://api.spotify.com/v1/audio-analysis/1gzI...       252200
# 19  https://api.spotify.com/v1/audio-analysis/4KfS...       261933
# 20  https://api.spotify.com/v1/audio-analysis/00qO...       259800
# 21  https://api.spotify.com/v1/audio-analysis/73Tx...       274088
# 22  https://api.spotify.com/v1/audio-analysis/2HXi...       246800
# 23  https://api.spotify.com/v1/audio-analysis/35k3...       221000
# 24  https://api.spotify.com/v1/audio-analysis/0vOk...       171267
# 25  https://api.spotify.com/v1/audio-analysis/6xMH...       268693
# 26  https://api.spotify.com/v1/audio-analysis/5B6Z...       265893
# 27  https://api.spotify.com/v1/audio-analysis/2oSp...       246933
# 28  https://api.spotify.com/v1/audio-analysis/2ccU...       253733
# 29  https://api.spotify.com/v1/audio-analysis/1ynm...       216533
# 30  https://api.spotify.com/v1/audio-analysis/7vid...       200213
# 31  https://api.spotify.com/v1/audio-analysis/3Pu3...       246573
# 32  https://api.spotify.com/v1/audio-analysis/3pHS...       132707
# 33  https://api.spotify.com/v1/audio-analysis/2cOp...       179600
# 34  https://api.spotify.com/v1/audio-analysis/0pow...       194893
# 35  https://api.spotify.com/v1/audio-analysis/4XId...       180373
# 36  https://api.spotify.com/v1/audio-analysis/47ji...       186480
# 37  https://api.spotify.com/v1/audio-analysis/3n5T...       201960
# 38  https://api.spotify.com/v1/audio-analysis/2joc...       181360
# 39  https://api.spotify.com/v1/audio-analysis/3RsL...       203200
# 40  https://api.spotify.com/v1/audio-analysis/2dMj...       242973
# 41  https://api.spotify.com/v1/audio-analysis/76iy...       225507
# 42  https://api.spotify.com/v1/audio-analysis/4kpe...       176360
# 43  https://api.spotify.com/v1/audio-analysis/5ilb...       218267
# 44  https://api.spotify.com/v1/audio-analysis/116k...       193547
# 45  https://api.spotify.com/v1/audio-analysis/0Uws...       218373
# 46  https://api.spotify.com/v1/audio-analysis/6L4P...       212813
# 47  https://api.spotify.com/v1/audio-analysis/4mGJ...       237947
# 48  https://api.spotify.com/v1/audio-analysis/6FkX...       189547
# 49  https://api.spotify.com/v1/audio-analysis/2MdS...       197160
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               4
# 46               4
# 47               4
# 48               4
# 49               4

# %% [markdown]
# After achieving the data from this playlist and comparing each song with its danceability, energy, and liveliness versus its acoustics and instrumentals, I can make conclusions and comparisons about my hypothesis.
#
# First, after working with the data for some time, I concluded that my hypothesis had the potential to be stronger. While the hypothesis wasn't "incomplete" I believe I could have developed a stronger hypothesis instead of using phrases such as, "on the higher end" and "contain higher numbers." While my hypothesis helps make conclusions and comparisons, I had the potential to make it stronger and develop a deeper and more robust hypothesis which may have allowed me to go beyond the surface level of the data. Nevertheless, the data I was able to produce allows me to answer the hypothesis as it was stated.
#
# Secondly, I am not afraid to admit that my professor helped and supported me through the gathering and development of this data. Based on his examples and lessons, I was able to work through and process this data. As I am working with the Spotify data, there are important pieces of information that are hidden to safeguard my data and information. However, with this information, I can work through a process of taking my playlist (The Ultimate Mixtape) and parsing out important keys to break down the internal data and, by using list comprehension, make inferences about the data. While there are limitations to the data, some resulting from my moderate hypothesis and others from my lack of experience working with this type of data, the information that I do have allows me to understand, on some level, the information on this playlist and inspire me to devel deeper into doing more with the data. Also, by being able to make charts and tables, I could simplify the data I would like to compare even more to make it more concise and organized.
#
# Nevertheless, the data I gained from this playlist allowed me to take the songs listed in my playlist, and compare the danceability, energy, and liveliness versus its acoustics and instrumentals within the song itself and with other songs listed. For example, song number 0 had a danceability of 0.532, energy of 0.767, and liveliness of 0.3900 as compared to its acoustics of 0.002870 and instrumentalness of 0.000513. If I were to compare this song with itself, I can determine that it supports my hypothesis that danceability, energy, and liveliness contain "higher numbers" as compared to that of acoustics and instrumentalness.
#
# I can also support my hypothesis that danceability, energy, and liveliness contain "higher numbers" as compared to that of acoustics and instrumentalness between the songs and not just one song. In other words, if I were to compare these statistics in song 1 and song 2:
#
# Song 1 contains 0.502(danceability), 0.890(energy), and 0.2170(liveliness) versus its 0.000147(acoustics) and 0.011700(instrumentalness).
#
# Song 2 contains 0.541(danceability), 0.960(energy), and 0.3440(liveliness), versus its 0.066300(acoustics) and	0.000002(instrumentalness).
#
# By comparing these two songs I can determine that they have "higher numbers." in danceability, energy, and liveliness. I believe if I were to cross reference all songs listed in the data frame, I could take the data, and by determining the name of the songs listed, I can support the theory that the country, rock, and pop songs, are the songs resulting in higher numbers.
#
# While there may be limitations to this data, the information that I have developed allows me to understand the data and make inferences and conclusions.
