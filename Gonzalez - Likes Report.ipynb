# %% [markdown]
# # Dominic's Likes Report 9.15.23
#
# Theoretical Hypothesis - I think my most liked accounts are going to be the people I follow. I do not think there will be many accounts that I do not follow that will show up in my data as likes since I do not usually scroll on instagram other than the people I follow.
#
# Statistical Hypothesis - I think that by analyzing the number of likes based on each profile I follow and cross refrencing them to account that I do not follow, I can use the amount of likes to determine that I tend to like posts associated with people that I follow.
#
#
# The data included in my liked_posts.json is appropriate for testing my hypothesis because I will have the chance to see what posts I like whether they are people I follow or random accounts that are targerted towards me.

# %% [markdown]
# Who collected this data? -- I believe Instagram and Meta collected this data
#
# Why was this data collected? -- I believe this data was collected for targerted advertising and to provide recommedations that they believe I would like. I think this becasue according to my main feed, I have many jokes and products that I am interested in. For some time, Instagram showed me a lot of workout videos and videos related to firefighting as I had liked a few posts related to this content.
#
# In what ways may this data be reliable? - This data may be reliable because it shows me information that and proudcts that I am interested in. Therefore, it can use the data its collected from me to target my interestes and get me to continue using Instagram.
#
# In what ways may this data be unreliable? - This data may be unreliable because it may not be aware of things I am interested in. The data may also be unreliable because Instagram cannot perfectly determine complete data about a single person and what all their likes and interested may be.

# %%
import pandas as pd
import json

# %%
with open(r"/Users/drgonzo1/Documents/Data in EMAT/dom.gonzo118_20230905 (1)/likes/liked_posts.json") as ld:
    like_data = json.load(ld)

# %%
like_data.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
liked_parts = pd.DataFrame(like_data['likes_media_likes'])

# %%
liked_parts.head()
# Out:
#             title                                   string_list_data
# 0  alexasummer.21  [{'href': 'https://www.instagram.com/p/Cwqlt3K...
# 1     keeplauren_  [{'href': 'https://www.instagram.com/p/Cwle-1L...
# 2  lydiajerina_14  [{'href': 'https://www.instagram.com/p/Cwhvj8l...
# 3          kamyj_  [{'href': 'https://www.instagram.com/p/Cwg5ygr...
# 4    izzzybella92  [{'href': 'https://www.instagram.com/p/CwfKYeN...

# %%
like_data['likes_media_likes'][0:10]
# Out:
# [{'title': 'alexasummer.21',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1693621605}]},
#  {'title': 'keeplauren_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cwle-1LuPxZ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1693439363}]},
#  {'title': 'lydiajerina_14',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cwhvj8lO6-J/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1693318824}]},
#  {'title': 'kamyj_',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cwg5ygrOnQn/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1693281753}]},
#  {'title': 'izzzybella92',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/CwfKYeNLRd_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1693240993}]},
#  {'title': 'liberty.mosher',
#   'string_list_data': [{'href': 'https://www.instagram.com/p/Cwfs-fDO3bP/',
# ...

# %%
like_data['likes_media_likes'][0]
# Out:
# {'title': 'alexasummer.21',
#  'string_list_data': [{'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693621605}]}

# %%
like_data['likes_media_likes'][0]['string_list_data']
# Out:
# [{'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693621605}]

# %%
like_data['likes_media_likes'][0]['string_list_data'][0]
# Out:
# {'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1693621605}

# %%
like_data['likes_media_likes'][0]['string_list_data'][0]['timestamp']
# Out:
# 1693621605

# %%
users = [x['string_list_data'] for x in like_data['likes_media_likes']]
users[0:10]
# Out:
# [[{'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693621605}],
#  [{'href': 'https://www.instagram.com/p/Cwle-1LuPxZ/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693439363}],
#  [{'href': 'https://www.instagram.com/p/Cwhvj8lO6-J/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693318824}],
#  [{'href': 'https://www.instagram.com/p/Cwg5ygrOnQn/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693281753}],
#  [{'href': 'https://www.instagram.com/p/CwfKYeNLRd_/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693240993}],
#  [{'href': 'https://www.instagram.com/p/Cwfs-fDO3bP/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693240987}],
#  [{'href': 'https://www.instagram.com/p/CwYxK48rQu1/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1693020168}],
#  [{'href': 'https://www.instagram.com/p/CwU--qvOSs3/',
#    'value': 'ð\x9f\x91\x8d',
#    'timestamp': 1692888813}],
# ...

# %%
users = [x['string_list_data'][0] for x in like_data['likes_media_likes']]
users[0:10]
# Out:
# [{'href': 'https://www.instagram.com/p/Cwqlt3KuTOx/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693621605},
#  {'href': 'https://www.instagram.com/p/Cwle-1LuPxZ/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693439363},
#  {'href': 'https://www.instagram.com/p/Cwhvj8lO6-J/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693318824},
#  {'href': 'https://www.instagram.com/p/Cwg5ygrOnQn/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693281753},
#  {'href': 'https://www.instagram.com/p/CwfKYeNLRd_/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693240993},
#  {'href': 'https://www.instagram.com/p/Cwfs-fDO3bP/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693240987},
#  {'href': 'https://www.instagram.com/p/CwYxK48rQu1/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1693020168},
#  {'href': 'https://www.instagram.com/p/CwU--qvOSs3/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1692888813},
#  {'href': 'https://www.instagram.com/p/CwSstYcOzoI/',
# ...

# %%
users = [x['string_list_data'][0]['timestamp'] for x in like_data['likes_media_likes']]
users[0:10]
# Out:
# [1693621605,
#  1693439363,
#  1693318824,
#  1693281753,
#  1693240993,
#  1693240987,
#  1693020168,
#  1692888813,
#  1692813871,
#  1692656404]

# %%
liked_parts['timestamp'] = users
liked_parts.head()
# Out:
#             title                                   string_list_data  \
# 0  alexasummer.21  [{'href': 'https://www.instagram.com/p/Cwqlt3K...
# 1     keeplauren_  [{'href': 'https://www.instagram.com/p/Cwle-1L...
# 2  lydiajerina_14  [{'href': 'https://www.instagram.com/p/Cwhvj8l...
# 3          kamyj_  [{'href': 'https://www.instagram.com/p/Cwg5ygr...
# 4    izzzybella92  [{'href': 'https://www.instagram.com/p/CwfKYeN...
#
#     timestamp
# 0  1693621605
# 1  1693439363
# 2  1693318824
# 3  1693281753
# 4  1693240993

# %%
liked_parts\
.groupby('title')\
.count()\
.sort_values('string_list_data', ascending = False).head(60)
# Out:
#                        string_list_data  timestamp
# title
# roldan_239                          403        403
# ndcl_school                         346        346
# rosannapansino                      215        215
# salty_soul70                        211        211
# coach_mooney81                      187        187
# starwarsdaily                       166        166
# matpatgt                            164        164
# cordypatrick                        154        154
# iceman42_                           143        143
# ali.morgan7                         116        116
# gracieladamato                      112        112
# phallon_ray19                       103        103
# kingjames                            98         98
# brynnmorgan__                        90         90
# sonicthehedgehog                     82         82
# julianakless33                       78         78
# liberty.mosher                       76         76
# ...

# %% [markdown]
# After going back and revising the code, I can see the first 60 accounts whose profiles and posts I have liked. As with my hypothesis and interpretation of the data (based on the accounts I can view), I have concluded that more of my likes relate to accounts that I follow. I went through the list and compiled the accounts that I do follow versus the ones that I do not. After compiling them, the data showed that I have liked more posts based on accounts that I follow as predicted in my hypothesis. There are many accounts the data shows that I do not follow anymore, but have in the past. Therefore, I think it would be interesting to take only the accounts that I follow now (as the number has gone from about 300 to 86) and cross reference the 86 current accounts to accounts/posts that I have liked but do not follow. However, as the data comes from my history on Instagram, I am shown the accounts from years past.
